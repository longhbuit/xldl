# %%
! pip install datasets scikit-learn seaborn matplotlib joblib kagglehub plotly
# Out:
# Requirement already satisfied: datasets in d:\pycharmprojects\xldl\.venv\lib\site-packages (4.4.2)
# Requirement already satisfied: scikit-learn in d:\pycharmprojects\xldl\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: seaborn in d:\pycharmprojects\xldl\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in d:\pycharmprojects\xldl\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: joblib in d:\pycharmprojects\xldl\.venv\lib\site-packages (1.5.3)
# Requirement already satisfied: kagglehub in d:\pycharmprojects\xldl\.venv\lib\site-packages (0.3.13)
# Collecting plotly
#   Downloading plotly-6.5.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: filelock in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (3.20.2)
# Requirement already satisfied: numpy>=1.17 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (2.4.0)
# Requirement already satisfied: pyarrow>=21.0.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (1.2.4)
# Requirement already satisfied: packaging in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in d:\pycharmprojects\xldl\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in d:\pycharmprojects\xldl\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: scipy>=1.10.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.15.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: pytz>=2020.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: colorama in d:\pycharmprojects\xldl\.venv\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Downloading plotly-6.5.1-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.9 MB 9.7 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.9 MB 10.3 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.1 MB/s eta 0:00:00
# Downloading narwhals-2.15.0-py3-none-any.whl (432 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.15.0 plotly-6.5.1
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arshkon/linkedin-job-postings")
import os

os.listdir(path)
# Out:
# ['companies', 'jobs', 'mappings', 'postings.csv']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df_posting = pd.read_csv(f'{path}/postings.csv')
df_posting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123849 entries, 0 to 123848
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   job_id                      123849 non-null  int64
#  1   company_name                122130 non-null  object
#  2   title                       123849 non-null  object
#  3   description                 123842 non-null  object
#  4   max_salary                  29793 non-null   float64
#  5   pay_period                  36073 non-null   object
#  6   location                    123849 non-null  object
#  7   company_id                  122132 non-null  float64
#  8   views                       122160 non-null  float64
#  9   med_salary                  6280 non-null    float64
#  10  min_salary                  29793 non-null   float64
#  11  formatted_work_type         123849 non-null  object
#  12  applies                     23320 non-null   float64
#  13  original_listed_time        123849 non-null  float64
#  14  remote_allowed              15246 non-null   float64
#  15  job_posting_url             123849 non-null  object
#  16  application_url             87184 non-null   object
#  17  application_type            123849 non-null  object
#  18  expiry                      123849 non-null  float64
#  19  closed_time                 1073 non-null    float64
#  20  formatted_experience_level  94440 non-null   object
#  21  skills_desc                 2439 non-null    object
#  22  listed_time                 123849 non-null  float64
#  23  posting_domain              83881 non-null   object
#  24  sponsored                   123849 non-null  int64
#  25  work_type                   123849 non-null  object
#  26  currency                    36073 non-null   object
#  27  compensation_type           36073 non-null   object
#  28  normalized_salary           36073 non-null   float64
#  29  zip_code                    102977 non-null  float64
#  30  fips                        96434 non-null   float64
# dtypes: float64(14), int64(2), object(15)
# memory usage: 29.3+ MB

# %%
# Hiển thị 5 dòng đầu và 5 dòng ngẫu nhiên để có cái nhìn tổng quan
display(df_posting.head())
display(df_posting.sample(5))
# Out:
#      job_id            company_name  \
# 0    921716   Corcoran Sawyer Smith
# 1   1829192                     NaN
# 2  10998357  The National Exemplar
# 3  23221523  Abrams Fensterman, LLP
# 4  35982263                     NaN
#
#                                                title  \
# 0                              Marketing Coordinator
# 1                  Mental Health Therapist/Counselor
# 2                        Assitant Restaurant Manager
# 3  Senior Elder Law / Trusts and Estates Associat...
# 4                                 Service Technician
#
#                                          description  max_salary pay_period  \
# 0  Job descriptionA leading real estate firm in N...        20.0     HOURLY
# 1  At Aspen Therapy and Wellness , we are committ...        50.0     HOURLY
# 2  The National Exemplar is accepting application...     65000.0     YEARLY
# 3  Senior Associate Attorney - Elder Law / Trusts...    175000.0     YEARLY
# 4  Looking for HVAC service tech with experience ...     80000.0     YEARLY
#
#             location  company_id  views  med_salary  ...  \
# 0      Princeton, NJ   2774458.0   20.0         NaN  ...
# 1   Fort Collins, CO         NaN    1.0         NaN  ...
# 2     Cincinnati, OH  64896719.0    8.0         NaN  ...
# 3  New Hyde Park, NY    766262.0   16.0         NaN  ...
# 4     Burlington, IA         NaN    3.0         NaN  ...
#
#                                          skills_desc   listed_time  \
# 0  Requirements: \n\nWe are seeking a College or ...  1.713398e+12
# 1                                                NaN  1.712858e+12
# 2  We are currently accepting resumes for FOH - A...  1.713278e+12
# 3  This position requires a baseline understandin...  1.712896e+12
# 4                                                NaN  1.713452e+12
#
#    posting_domain  sponsored  work_type currency compensation_type  \
# 0             NaN          0  FULL_TIME      USD       BASE_SALARY
# 1             NaN          0  FULL_TIME      USD       BASE_SALARY
# 2             NaN          0  FULL_TIME      USD       BASE_SALARY
# 3             NaN          0  FULL_TIME      USD       BASE_SALARY
# 4             NaN          0  FULL_TIME      USD       BASE_SALARY
#
#   normalized_salary  zip_code     fips
# 0           38480.0    8540.0  34021.0
# 1           83200.0   80521.0   8069.0
# 2           55000.0   45202.0  39061.0
# 3          157500.0   11040.0  36059.0
# 4           70000.0   52601.0  19057.0
#
# [5 rows x 31 columns]
#            job_id                                    company_name  \
# 53090  3901635393                                      Five Below
# 44450  3900941611                                    FedEx Ground
# 94043  3904722362                       Nexstar Media Group, Inc.
# 30029  3894546416                                     Capital One
# 5808   3885104447  Liberty Healthcare and Rehabilitation Services
#
#                                                    title  \
# 53090                                Merchandise Manager
# 44450  Package Handler - Part & Full Time (Warehouse ...
# 94043                                 Operator I, Camera
# 30029  Senior Lead Engineer - Generative AI Infrastru...
# 5808    PHYSICAL THERAPIST - SHORELAND HEALTHCARE CENTER
#
#                                              description  max_salary  \
# 53090  At Five Below our growth is a result of the pe...         NaN
# 44450  IMMEDIATE OPENINGS!\n\nCome for a job and stay...         NaN
# 94043  The Camera Operator is responsible for operati...         NaN
# 30029  NYC 299 Park Avenue (22957), United States of ...         NaN
# 5808   \nLiberty Cares With Compassion\n\n***$10,000 ...         NaN
#
#       pay_period           location  company_id  views  med_salary  ...  \
# 53090        NaN        Houston, TX     49041.0   12.0         NaN  ...
# 44450        NaN     Lincolnton, NC      1668.0    3.0         NaN  ...
# 94043        NaN     Sioux City, IA    347410.0    3.0         NaN  ...
# 30029        NaN  San Francisco, CA      1419.0    4.0         NaN  ...
# 5808         NaN     Whiteville, NC  53345529.0    2.0         NaN  ...
#
#        skills_desc   listed_time                   posting_domain  sponsored  \
# 53090          NaN  1.713211e+12  fivebelow.wd1.myworkdayjobs.com          0
# 44450          NaN  1.713388e+12    groundwarehousejobs.fedex.com          0
# 94043          NaN  1.713566e+12    nexstar.wd5.myworkdayjobs.com          0
# 30029          NaN  1.712885e+12                      dsp.prng.co          0
# 5808           NaN  1.712401e+12              www.click2apply.net          0
#
#        work_type currency compensation_type normalized_salary  zip_code  \
# 53090  FULL_TIME      NaN               NaN               NaN   77002.0
# 44450  FULL_TIME      NaN               NaN               NaN   28092.0
# 94043  PART_TIME      NaN               NaN               NaN   51101.0
# 30029  FULL_TIME      NaN               NaN               NaN   94101.0
# 5808   FULL_TIME      NaN               NaN               NaN   28472.0
#
#           fips
# 53090  48201.0
# 44450  37109.0
# 94043  19193.0
# 30029   6075.0
# 5808   37047.0
#
# [5 rows x 31 columns]

# %%
# Tính phần trăm missing value cho từng cột và sắp xếp giảm dần
missing_percent = df_posting.isnull().mean() * 100
print(missing_percent[missing_percent > 0].sort_values(ascending=False))
# Out:
# closed_time                   99.133622
# skills_desc                   98.030666
# med_salary                    94.929309
# remote_allowed                87.689848
# applies                       81.170619
# min_salary                    75.944093
# max_salary                    75.944093
# pay_period                    70.873402
# compensation_type             70.873402
# normalized_salary             70.873402
# currency                      70.873402
# posting_domain                32.271556
# application_url               29.604599
# formatted_experience_level    23.745852
# fips                          22.135827
# zip_code                      16.852780
# company_name                   1.387981
# company_id                     1.386366
# views                          1.363757
# description                    0.005652
# dtype: float64

# %%
# Kiểm tra phân phối của các cột quan trọng
cols_to_check = ['formatted_work_type', 'formatted_experience_level', 'remote_allowed', 'pay_period']

for col in cols_to_check:
    print(f"--- Phân phối giá trị của cột: {col} ---")
    print(df_posting[col].value_counts(dropna=False))
    print("\n")
# Out:
# --- Phân phối giá trị của cột: formatted_work_type ---
# formatted_work_type
# Full-time     98814
# Contract      12117
# Part-time      9696
# Temporary      1190
# Internship      983
# Volunteer       562
# Other           487
# Name: count, dtype: int64
#
#
# --- Phân phối giá trị của cột: formatted_experience_level ---
# formatted_experience_level
# Mid-Senior level    41489
# Entry level         36708
# NaN                 29409
# Associate            9826
# Director             3746
# Internship           1449
# Executive            1222
# Name: count, dtype: int64
#
#
# --- Phân phối giá trị của cột: remote_allowed ---
# remote_allowed
# NaN    108603
# 1.0     15246
# Name: count, dtype: int64
#
#
# --- Phân phối giá trị của cột: pay_period ---
# pay_period
# NaN         87776
# YEARLY      20628
# HOURLY      14741
# MONTHLY       518
# WEEKLY        177
# BIWEEKLY        9
# Name: count, dtype: int64

# %%
# Xem thống kê mô tả (mean, min, max, std) của các cột số
display(df_posting[['max_salary', 'min_salary', 'views', 'applies']].describe())
# Out:
#          max_salary    min_salary          views       applies
# count  2.979300e+04  2.979300e+04  122160.000000  23320.000000
# mean   9.193942e+04  6.491085e+04      14.618247     10.591981
# std    7.011101e+05  4.959738e+05      85.903598     29.047395
# min    1.000000e+00  1.000000e+00       1.000000      1.000000
# 25%    4.828000e+01  3.700000e+01       3.000000      1.000000
# 50%    8.000000e+04  6.000000e+04       4.000000      3.000000
# 75%    1.400000e+05  1.000000e+05       8.000000      8.000000
# max    1.200000e+08  8.500000e+07    9975.000000    967.000000

# %%
# --- 1. XỬ LÝ DỮ LIỆU (Giống bước trước) ---
df_clean = df_posting.copy()

# Xử lý remote_allowed và thời gian
df_clean['remote_allowed'] = df_clean['remote_allowed'].fillna(0).astype(int)
df_clean['listed_time'] = pd.to_datetime(df_clean['listed_time'], unit='ms')

# Chỉ lấy đơn vị tiền tệ USD
if 'currency' in df_clean.columns:
    df_clean = df_clean[df_clean['currency'].isin(['USD', pd.NA, None])]

# Tính lương trung bình và chuẩn hóa về Lương Năm
df_clean['avg_salary'] = (df_clean['min_salary'] + df_clean['max_salary']) / 2

def standardize_salary(row):
    salary = row['avg_salary']
    period = row['pay_period']
    if pd.isna(salary): return None
    if period == 'HOURLY': return salary * 40 * 52
    if period == 'MONTHLY': return salary * 12
    if period == 'WEEKLY': return salary * 52
    return salary

df_clean['yearly_salary'] = df_clean.apply(standardize_salary, axis=1)

# Lọc bỏ ngoại lai (Outliers)
df_clean = df_clean[
    (df_clean['yearly_salary'].isnull()) |
    ((df_clean['yearly_salary'] >= 15000) & (df_clean['yearly_salary'] <= 600000))
]

# %%
import plotly.express as px
# --- BƯỚC 3: LOẠI BỎ NGOẠI LAI (OUTLIERS) ---

print(f"Số lượng bản ghi có dữ liệu lương hợp lệ: {df_clean['yearly_salary'].count()}")

# Vẽ Histogram
fig = px.histogram(
    df_clean,
    x='yearly_salary',
    nbins=50,
    title='Phân phối Lương theo Năm (USD) - Biểu đồ Tương tác',
    labels={'yearly_salary': 'Mức lương (USD/năm)', 'count': 'Số lượng công việc'},
    template='plotly_white', # Giao diện sáng sủa
    marginal='box', # Thêm biểu đồ hộp (box plot) nhỏ ở trên để xem median/outlier
    color_discrete_sequence=['indianred'] # Đổi màu cột
)

# Hiển thị biểu đồ
fig.show()
# Out:
# Số lượng bản ghi có dữ liệu lương hợp lệ: 29340

# %%
fig.to_json()
# Out:
# '{"data":[{"bingroup":"x","hovertemplate":"M\\u1ee9c l\\u01b0\\u01a1ng (USD\\u002fn\\u0103m)=%{x}\\u003cbr\\u003ecount=%{y}\\u003cextra\\u003e\\u003c\\u002fextra\\u003e","legendgroup":"","marker":{"color":"indianred","pattern":{"shape":""}},"name":"","nbinsx":50,"orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"AAAAAADK4kAAAAAAAFD0QAAAAAAA2+pAAAAAAOA5A0EAAAAAABfxQAAAAAAAROFAAAAAAAD5BUEAAAAAgKL5QAAAAAAAAPh\\u002fAAAAAAAA+H8AAAAAAMriQAAAAAAAVOVAAAAAAAAA+H8AAAAAAL3vQAAAAACAhO5AAAAAAIAC6kAAAAAAAGr4QAAAAAAATP1AAAAAAABo6kAAAAAA4MgAQQAAAAAAve9AAAAAAIBP8kAAAAAAAPn1QAAAAAAAiPNAAAAAAADJ7UAAAAAAAL3\\u002fQAAAAADAevBAAAAAAABY5kAAAAAAAAD4fwAAAAAA2\\u002fpAAAAAAADa5kAAAAAAAOLoQAAAAAAAgQBBAAAAAIDA9EBmZmZm5m4BQQAAAAAARPFAAAAAAIAT7EAAAAAAAL3vQAAAAAAA6upAAAAAAACB8EAAAAAAAIjzQAAAAABAJPRAAAAAAAAA+H8AAAAAgE\\u002fyQAAAAAAA2+pAAAAAAAD59UAAAAAAAAD4fwAAAACAwPRAAAAAAAAA+H8AAAAAAOrqQAAAAACAMfdAAAAAAPgy9kAAAAAAwHoAQQAAAACAAe9AAAAAAIAR9EAAAAAAIIjTQAAAAAAAaOpAAAAAAMDrAkEAAAAAAO7rQAAAAACAMedAAAAAAAAA+H8AAAAAAAD4fwAAAACAT\\u002fJAAAAAAADa5kAAAAAAAO7rQAAAAABAJPRAAAAAAAB43kAAAAAAQLzxQAAAAAAA5+hAAAAAAADu+0AAAAAAAMriQAAAAAAAavhAAAAAAADa5kAAAAAAgE\\u002fyQAAAAAAAAPh\\u002fAAAAAAAX4UAAAAAAAAD4fwAAAAAAAPh\\u002fAAAAAMB0EUHMzMzMDP\\u002f2QAAAAADA6\\u002fJAAAAAAODv70AAAAAAAFTlQAAAAAAAA\\u002fFAAAAAAIDABEEAAAAAQLPxQAAAAAAAB\\\\u002fyQAAAAABg4wZBAAAAAAAX8UAAAAAAAEztQAAAAAAAruVAAAAAAEAG+UAAAAAAANblQAAAAADAXPVAAAAAAABS\\u002fEAAAAAAAAvjQAAAAAAA6upAAAAAAABk6UAAAAAAAEztQAAAAADAXPVAAAAAAADG4UAAAAAAAAD4fwAAAAAA+eVAAAAAAIDA9EAAAAAAAO3nQAAAAAAA2uZAAAAAAABk2UAAAAAAwHrw