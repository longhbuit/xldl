# %%
! pip install datasets scikit-learn seaborn matplotlib joblib kagglehub
# Out:
# Collecting datasets
#   Downloading datasets-4.4.2-py3-none-any.whl.metadata (19 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting joblib
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Collecting filelock (from datasets)
#   Downloading filelock-3.20.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting numpy>=1.17 (from datasets)
#   Downloading numpy-2.4.0-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-22.0.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: requests>=2.32.2 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (0.28.1)
# Collecting tqdm>=4.66.3 (from datasets)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py312-none-any.whl.metadata (7.5 kB)
# Collecting fsspec<=2025.10.0,>=2023.1.0 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface-hub<2.0,>=0.25.0 (from datasets)
#   Downloading huggingface_hub-1.2.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from datasets) (6.0.3)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: anyio in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting shellingham (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\pycharmprojects\xldl\.venv\lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: colorama in d:\pycharmprojects\xldl\.venv\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Collecting click>=8.0.0 (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Downloading datasets-4.4.2-py3-none-any.whl (512 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading huggingface_hub-1.2.4-py3-none-any.whl (520 kB)
# Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --------------------- ------------------ 1.6/2.9 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 6.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.18-py312-none-any.whl (150 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.0 MB 7.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.0 MB 8.0 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 8.4 MB/s eta 0:00:00
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 10.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 9.7 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl (455 kB)
# Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl (46 kB)
# Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------------ --- 2.1/2.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.4 MB/s eta 0:00:00
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading numpy-2.4.0-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.3 MB 10.7 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.3 MB 10.5 MB/s eta 0:00:01
#    -------------------- ------------------- 6.3/12.3 MB 10.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.3 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 10.3 MB/s eta 0:00:00
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Downloading pillow-12.1.0-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------- -------------- 4.5/7.0 MB 11.2 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 10.1 MB/s eta 0:00:00
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Downloading pyarrow-22.0.0-cp312-cp312-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    --- ------------------------------------ 2.4/28.0 MB 11.2 MB/s eta 0:00:03
#    ------ --------------------------------- 4.5/28.0 MB 11.2 MB/s eta 0:00:03
#    --------- ------------------------------ 6.8/28.0 MB 11.0 MB/s eta 0:00:02
#    ------------- -------------------------- 9.2/28.0 MB 11.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 11.5/28.0 MB 11.1 MB/s eta 0:00:02
#    ------------------- -------------------- 13.6/28.0 MB 11.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 16.0/28.0 MB 11.2 MB/s eta 0:00:02
#    -------------------------- ------------- 18.4/28.0 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 20.4/28.0 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 22.8/28.0 MB 11.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 25.2/28.0 MB 11.2 MB/s eta 0:00:01
#    -------------------------------------- - 26.7/28.0 MB 11.2 MB/s eta 0:00:01
#    -------------------------------------- - 27.0/28.0 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 9.9 MB/s eta 0:00:00
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl (38.6 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading filelock-3.20.2-py3-none-any.whl (16 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading xxhash-3.6.0-cp312-cp312-win_amd64.whl (31 kB)
# Installing collected packages: pytz, xxhash, tqdm, threadpoolctl, shellingham, pyparsing, pyarrow, propcache, pillow, numpy, multidict, kiwisolver, joblib, hf-xet, fsspec, frozenlist, fonttools, filelock, dill, cycler, click, aiohappyeyeballs, yarl, typer-slim, scipy, pandas, multiprocess, kagglehub, contourpy, aiosignal, scikit-learn, matplotlib, huggingface-hub, aiohttp, seaborn, datasets
#
#    ----------------------------------------  0/36 [pytz]
#    ----- ----------------------------------  5/36 [pyparsing]
#    ------ ---------------------------------  6/36 [pyarrow]
#    ------ ---------------------------------  6/36 [pyarrow]
#    ------ ---------------------------------  6/36 [pyarrow]
#    ------ ---------------------------------  6/36 [pyarrow]
#    ------ ---------------------------------  6/36 [pyarrow]
#    ------ ---------------------------------  6/36 [pyarrow]
#    -------- -------------------------------  8/36 [pillow]
#    -------- -------------------------------  8/36 [pillow]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ---------- -----------------------------  9/36 [numpy]
#    ------------- -------------------------- 12/36 [joblib]
#    ------------- -------------------------- 12/36 [joblib]
#    ------------- -------------------------- 12/36 [joblib]
#    -------------- ------------------------- 13/36 [hf-xet]
#    --------------- ------------------------ 14/36 [fsspec]
#    --------------- ------------------------ 14/36 [fsspec]
#    --------------- ------------------------ 14/36 [fsspec]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    ----------------- ---------------------- 16/36 [fonttools]
#    -------------------- ------------------- 18/36 [dill]
#    ------------------------ --------------- 22/36 [yarl]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    -------------------------- ------------- 24/36 [scipy]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    --------------------------- ------------ 25/36 [pandas]
#    ---------------------------- ----------- 26/36 [multiprocess]
#    ------------------------------ --------- 27/36 [kagglehub]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    --------------------------------- ------ 30/36 [scikit-learn]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ---------------------------------- ----- 31/36 [matplotlib]
#    ----------------------------------- ---- 32/36 [huggingface-hub]
#    ------------------------------------ --- 33/36 [aiohttp]
#    ------------------------------------ --- 33/36 [aiohttp]
#    ------------------------------------- -- 34/36 [seaborn]
#    -------------------------------------- - 35/36 [datasets]
#    -------------------------------------- - 35/36 [datasets]
#    ---------------------------------------- 36/36 [datasets]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 click-8.3.1 contourpy-1.3.3 cycler-0.12.1 datasets-4.4.2 dill-0.4.0 filelock-3.20.2 fonttools-4.61.1 frozenlist-1.8.0 fsspec-2025.10.0 hf-xet-1.2.0 huggingface-hub-1.2.4 joblib-1.5.3 kagglehub-0.3.13 kiwisolver-1.4.9 matplotlib-3.10.8 multidict-6.7.0 multiprocess-0.70.18 numpy-2.4.0 pandas-2.3.3 pillow-12.1.0 propcache-0.4.1 pyarrow-22.0.0 pyparsing-3.3.1 pytz-2025.2 scikit-learn-1.8.0 scipy-1.16.3 seaborn-0.13.2 shellingham-1.5.4 threadpoolctl-3.6.0 tqdm-4.67.1 typer-slim-0.21.1 xxhash-3.6.0 yarl-1.22.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arshkon/linkedin-job-postings")
import os

os.listdir(path)
# Out:
# ['companies', 'jobs', 'mappings', 'postings.csv']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df_posting = pd.read_csv(f'{path}/postings.csv')
df_posting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123849 entries, 0 to 123848
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   job_id                      123849 non-null  int64
#  1   company_name                122130 non-null  object
#  2   title                       123849 non-null  object
#  3   description                 123842 non-null  object
#  4   max_salary                  29793 non-null   float64
#  5   pay_period                  36073 non-null   object
#  6   location                    123849 non-null  object
#  7   company_id                  122132 non-null  float64
#  8   views                       122160 non-null  float64
#  9   med_salary                  6280 non-null    float64
#  10  min_salary                  29793 non-null   float64
#  11  formatted_work_type         123849 non-null  object
#  12  applies                     23320 non-null   float64
#  13  original_listed_time        123849 non-null  float64
#  14  remote_allowed              15246 non-null   float64
#  15  job_posting_url             123849 non-null  object
#  16  application_url             87184 non-null   object
#  17  application_type            123849 non-null  object
#  18  expiry                      123849 non-null  float64
#  19  closed_time                 1073 non-null    float64
#  20  formatted_experience_level  94440 non-null   object
#  21  skills_desc                 2439 non-null    object
#  22  listed_time                 123849 non-null  float64
#  23  posting_domain              83881 non-null   object
#  24  sponsored                   123849 non-null  int64
#  25  work_type                   123849 non-null  object
#  26  currency                    36073 non-null   object
#  27  compensation_type           36073 non-null   object
#  28  normalized_salary           36073 non-null   float64
#  29  zip_code                    102977 non-null  float64
#  30  fips                        96434 non-null   float64
# dtypes: float64(14), int64(2), object(15)
# memory usage: 29.3+ MB
